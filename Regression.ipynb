# %% [markdown]
# <a href="https://colab.research.google.com/github/nblakshmi/LINEAR-REGRESSION/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/home-rental.csv")

# %%
x = df[['size']]
y = df['rent_amount']

# %%
X_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_predict)
print("Mean Square Error:",mse)
# Out:
# Mean Square Error: 3781.01129644514

# %%
plt.scatter(x,y,color='purple')
plt.plot(x,model.predict(x),color="blue")
plt.xlabel("Area (sq ft)")
plt.ylabel("price($1000)")
plt.title("Linear Regression Example")
plt.show()
